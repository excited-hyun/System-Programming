# %% [markdown]
# # Import modules

# %%
import keras
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Activation
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K
from keras.utils.vis_utils import model_to_dot
from IPython.display import SVG
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Tuning parameters

# %%
epochs = 50
learning_rate=0.0005

# %%
batch_size = 128
num_classes = 10

# %% [markdown]
# # Data

# %% [markdown]
# ## Plot image

# %%
def plot_images(x, y_true, y_pred=None, size=(5, 5)):
    assert len(x) == len(y_true) == size[0] * size[1]
    
    fig, axes = plt.subplots(size[0], size[1])
    fig.subplots_adjust(hspace=0.5, wspace=0.1)

    for i, ax in enumerate(axes.flat):
        if x[i].shape[-1] == 1:
          ax.imshow(x[i].reshape(x[i].shape[0], x[i].shape[1]))
        else:
          ax.imshow(x[i])

        if y_pred is None:
            xlabel = "True: {0}".format(y_true[i].argmax())
        else:
            xlabel = "True: {0}, Pred: {1}".format(y_true[i].argmax(), 
                                                   y_pred[i].argmax())

        ax.set_xlabel(xlabel)
        
        ax.set_xticks([])
        ax.set_yticks([])

    plt.show()

# %% [markdown]
# ## Load dataset

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %% [markdown]
# ## Reshaping the data

# %%
if len(x_train.shape) < 4:
  x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
  x_test = x_test.reshape(x_test.shape[0], x_train.shape[1], x_train.shape[2], 1)

# %%
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %% [markdown]
# ## Applying One hot encoding for the data

# %%
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %% [markdown]
# ## Show data

# %%
plot_images(x_train[:25], y_train[:25])

# %% [markdown]
# # Creating the DNN model

# %%
model = Sequential()

# %% [markdown]
# ## Adding layers to the model

# %%
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', 
                 input_shape=x_train.shape[1:]))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(Conv2D(256, (2, 2), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(512, (2, 2), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))



model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

# %% [markdown]
# ## Visualization the model

# %%
SVG(model_to_dot(model, show_shapes=True, dpi=60).create(prog='dot', format='svg'))

# %% [markdown]
# ## Optimizer

# %%
optimizer = keras.optimizers.Adam(lr=learning_rate)

# %% [markdown]
# ## Compiling the model

# %%
model.compile(loss=keras.losses.categorical_crossentropy, 
              optimizer=optimizer, 
              metrics=['accuracy'])

# %% [markdown]
# ## Training the model

# %%
model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test))
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 19s 382us/step - loss: 1.8853 - accuracy: 0.2901 - val_loss: 1.4761 - val_accuracy: 0.4548
# Epoch 2/50
# 50000/50000 [==============================] - 19s 373us/step - loss: 1.4219 - accuracy: 0.4855 - val_loss: 1.1729 - val_accuracy: 0.5783
# Epoch 3/50
# 50000/50000 [==============================] - 19s 372us/step - loss: 1.1999 - accuracy: 0.5763 - val_loss: 1.0635 - val_accuracy: 0.6200
# Epoch 4/50
# 50000/50000 [==============================] - 19s 372us/step - loss: 1.0598 - accuracy: 0.6301 - val_loss: 0.9350 - val_accuracy: 0.6703
# Epoch 5/50
# 50000/50000 [==============================] - 19s 371us/step - loss: 0.9506 - accuracy: 0.6712 - val_loss: 0.8389 - val_accuracy: 0.7073
# Epoch 6/50
# 50000/50000 [==============================] - 19s 372us/step - loss: 0.8645 - accuracy: 0.7020 - val_loss: 0.8036 - val_accuracy: 0.7230
# Epoch 7/50
# 50000/50000 [==============================] - 19s 371us/step - loss: 0.7960 - accuracy: 0.7268 - val_loss: 0.7660 - val_accuracy: 0.7366
# Epoch 8/50
# 50000/50000 [==============================] - 19s 372us/step - loss: 0.7438 - accuracy: 0.7455 - val_loss: 0.7173 - val_accuracy: 0.7506
# Epoch 9/50
# 50000/50000 [==============================] - 19s 372us/step - loss: 0.6974 - accuracy: 0.7613 - val_loss: 0.6852 - val_accuracy: 0.7620
# Epoch 10/50
# 50000/50000 [==============================] - 19s 374us/step - loss: 0.6466 - accuracy: 0.7805 - val_loss: 0.6603 - val_accuracy: 0.7683
# Epoch 11/50
# 50000/50000 [==============================] - 19s 376us/step - loss: 0.6114 - accuracy: 0.7934 - val_loss: 0.6374 - val_accuracy: 0.7800
# Epoch 12/50
# 50000/50000 [==============================] - 19s 371us/step - loss: 0.5793 - accuracy: 0.8023 - val_loss: 0.6332 - val_accuracy: 0.7827
# Epoch 13/50
# 50000/50000 [==============================] - 18s 370us/step - loss: 0.5486 - accuracy: 0.8140 - val_loss: 0.6059 - val_accuracy: 0.7928
# Epoch 14/50
# 50000/50000 [==============================] - 19s 372us/step - loss: 0.5082 - accuracy: 0.8271 - val_loss: 0.6190 - val_accuracy: 0.7932
# Epoch 15/50
# 50000/50000 [==============================] - 18s 369us/step - loss: 0.4829 - accuracy: 0.8353 - val_loss: 0.6065 - val_accuracy: 0.7986
# Epoch 16/50
# 50000/50000 [==============================] - 18s 370us/step - loss: 0.4570 - accuracy: 0.8447 - val_loss: 0.6158 - val_accuracy: 0.7926
# Epoch 17/50
# 50000/50000 [==============================] - 19s 371us/step - loss: 0.4341 - accuracy: 0.8530 - val_loss: 0.6018 - val_accuracy: 0.8018
# Epoch 18/50
# 50000/50000 [==============================] - 18s 370us/step - loss: 0.4114 - accuracy: 0.8592 - val_loss: 0.5991 - val_accuracy: 0.8032
# Epoch 19/50
# 50000/50000 [==============================] - 19s 371us/step - loss: 0.3935 - accuracy: 0.8663 - val_loss: 0.5996 - val_accuracy: 0.8042
# Epoch 20/50
# 50000/50000 [==============================] - 19s 372us/step - loss: 0.3725 - accuracy: 0.8721 - val_loss: 0.5915 - val_accuracy: 0.8082
# Epoch 21/50
# 50000/50000 [==============================] - 19s 370us/step - loss: 0.3537 - accuracy: 0.8801 - val_loss: 0.5992 - val_accuracy: 0.8077
# Epoch 22/50
# 50000/50000 [==============================] - 18s 369us/step - loss: 0.3337 - accuracy: 0.8857 - val_loss: 0.5927 - val_accuracy: 0.8127
# Epoch 23/50
# 50000/50000 [==============================] - 18s 368us/step - loss: 0.3189 - accuracy: 0.8904 - val_loss: 0.5938 - val_accuracy: 0.8144
# Epoch 24/50
# 50000/50000 [==============================] - 18s 369us/step - loss: 0.3002 - accuracy: 0.8980 - val_loss: 0.6162 - val_accuracy: 0.8159
# Epoch 25/50
# 50000/50000 [==============================] - 18s 369us/step - loss: 0.2937 - accuracy: 0.8994 - val_loss: 0.5881 - val_accuracy: 0.8133
# Epoch 26/50
# 50000/50000 [==============================] - 18s 368us/step - loss: 0.2754 - accuracy: 0.9038 - val_loss: 0.6098 - val_accuracy: 0.8179
# Epoch 27/50
# 50000/50000 [==============================] - 19s 373us/step - loss: 0.2675 - accuracy: 0.9078 - val_loss: 0.6029 - val_accuracy: 0.8183
# Epoch 28/50
# 50000/50000 [==============================] - 19s 371us/step - loss: 0.2540 - accuracy: 0.9111 - val_loss: 0.6193 - val_accuracy: 0.8171
# Epoch 29/50
# 50000/50000 [==============================] - 18s 368us/step - loss: 0.2453 - accuracy: 0.9150 - val_loss: 0.6125 - val_accuracy: 0.8191
# Epoch 30/50
# 50000/50000 [==============================] - 18s 367us/step - loss: 0.2367 - accuracy: 0.9187 - val_loss: 0.6136 - val_accuracy: 0.8160
# Epoch 31/50
# 50000/50000 [==============================] - 18s 367us/step - loss: 0.2309 - accuracy: 0.9196 - val_loss: 0.6321 - val_accuracy: 0.8190
# Epoch 32/50
# 50000/50000 [==============================] - 18s 367us/step - loss: 0.2182 - accuracy: 0.9240 - val_loss: 0.6381 - val_accuracy: 0.8218
# Epoch 33/50
# 50000/50000 [==============================] - 18s 367us/step - loss: 0.2115 - accuracy: 0.9277 - val_loss: 0.6671 - val_accuracy: 0.8140
# Epoch 34/50
# 50000/50000 [==============================] - 18s 366us/step - loss: 0.2068 - accuracy: 0.9296 - val_loss: 0.6463 - val_accuracy: 0.8198
# Epoch 35/50
# 50000/50000 [==============================] - 18s 367us/step - loss: 0.1921 - accuracy: 0.9350 - val_loss: 0.6690 - val_accuracy: 0.8147
# Epoch 36/50
# 50000/50000 [==============================] - 18s 368us/step - loss: 0.1869 - accuracy: 0.9370 - val_loss: 0.6731 - val_accuracy: 0.8177
# Epoch 37/50
# 50000/50000 [==============================] - 18s 367us/step - loss: 0.1860 - accuracy: 0.9361 - val_loss: 0.6542 - val_accuracy: 0.8226
# Epoch 38/50
# 50000/50000 [==============================] - 18s 367us/step - loss: 0.1766 - accuracy: 0.9406 - val_loss: 0.6811 - val_accuracy: 0.8217
# Epoch 39/50
# 50000/50000 [==============================] - 18s 366us/step - loss: 0.1731 - accuracy: 0.9400 - val_loss: 0.6885 - val_accuracy: 0.8172
# Epoch 40/50
# 50000/50000 [==============================] - 18s 367us/step - loss: 0.1686 - accuracy: 0.9412 - val_loss: 0.6843 - val_accuracy: 0.8195
# Epoch 41/50
# 50000/50000 [==============================] - 18s 366us/step - loss: 0.1636 - accuracy: 0.9432 - val_loss: 0.6665 - val_accuracy: 0.8215
# Epoch 42/50
# 50000/50000 [==============================] - 18s 367us/step - loss: 0.1597 - accuracy: 0.9462 - val_loss: 0.7006 - val_accuracy: 0.8218
# Epoch 43/50
# 50000/50000 [==============================] - 18s 366us/step - loss: 0.1556 - accuracy: 0.9463 - val_loss: 0.7172 - val_accuracy: 0.8201
# Epoch 44/50
# 50000/50000 [==============================] - 19s 373us/step - loss: 0.1531 - accuracy: 0.9483 - val_loss: 0.7473 - val_accuracy: 0.8128
# Epoch 45/50
# 50000/50000 [==============================] - 18s 369us/step - loss: 0.1519 - accuracy: 0.9491 - val_loss: 0.7059 - val_accuracy: 0.8202
# Epoch 46/50
# 50000/50000 [==============================] - 18s 367us/step - loss: 0.1414 - accuracy: 0.9524 - val_loss: 0.7280 - val_accuracy: 0.8199
# Epoch 47/50
# 50000/50000 [==============================] - 18s 366us/step - loss: 0.1383 - accuracy: 0.9532 - val_loss: 0.7431 - val_accuracy: 0.8229
# Epoch 48/50
# 50000/50000 [==============================] - 18s 365us/step - loss: 0.1373 - accuracy: 0.9533 - val_loss: 0.7494 - val_accuracy: 0.8201
# Epoch 49/50
# 50000/50000 [==============================] - 18s 367us/step - loss: 0.1391 - accuracy: 0.9531 - val_loss: 0.7792 - val_accuracy: 0.8227
# Epoch 50/50
# 50000/50000 [==============================] - 18s 369us/step - loss: 0.1390 - accuracy: 0.9529 - val_loss: 0.7485 - val_accuracy: 0.8206

# %% [markdown]
# ## Evaulating the model

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.7484726141929626
# Test accuracy: 0.8205999732017517

# %% [markdown]
# ## Prediction the model

# %%
y_pred = model.predict(x_test)

# %%
plot_images(x=x_test[:25], y_true=y_test[:25], y_pred=y_pred[:25])

# %%
y_result = confusion_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))
sns.heatmap(pd.DataFrame(y_result, range(10), range(10)), annot=True, fmt='g')
